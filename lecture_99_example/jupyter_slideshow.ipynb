# %% [markdown]
# # Main slide

# %% [markdown]
# ## Sub slide

# %% [markdown]
# ### Cell used as a fragment of previous

# %% [markdown]
# To change cell behavior: View -> Cell Toolbar -> Slideshow
#
#
# ![image.png](attachment:image.png)
#
# Choose appropriate type here.

# %% [markdown]
# ### To run presentation: alt / ⌥ + R

# %% [markdown]
# ### To run presentation: alt / ⌥ + R

# %% [markdown]
# ### Cell used as a fragment of previous

# %% [markdown]
# To change cell behavior: View -> Cell Toolbar -> Slideshow
#
#
# ![image.png](attachment:image.png)
#
# Choose appropriate type here.

# %% [markdown]
# ### To run presentation: alt / ⌥ + R
